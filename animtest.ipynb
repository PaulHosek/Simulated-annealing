# %%
from charges import Charges
from plotting import *
import matplotlib.pyplot as plt

# %matplotlib widget

methods = ["linear", "exponential_even_spacing", "exponential_0.003"]

n = 16
method = methods[0]
iterations = 100
markov = 5

ch = Charges(n, step_size=0.001)
# plot_points(ch.particles)

anim = animate_convergence(ch, 0.1, 50, iterations, method, markov, True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Iteration 100/100 at 0.1 degrees, energy: 117.3894999959821339999756796591

# %%
plot_points(ch.particles, charge=ch, force=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
